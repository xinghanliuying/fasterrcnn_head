# %%
#%cd ../input/fasterrcnn-bus
#import shutil
#shutil.copytree(r'../input/fasterrcnn-head', r'./fast')
#%pip install -r requirements.txt

# %%
# %cd

# %%
# %cd /kaggle

# %%
# %cd input/fasterrcnn-bus-v4

# %%
# %pip install -r requirements.txt

# %%
# !python train_res50_fpn.py --data-path /kaggle/input/mydatas-v2 --output-dir /kaggle/working --epochs 100 --num-classes 1

# %%
os.makedirs("/kaggle/working/out")
